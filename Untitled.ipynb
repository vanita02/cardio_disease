# %%
# %run model_build.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File D:\ML_PROJECT\disease_project\model_build.py:19
#      13 from sklearn.metrics import accuracy_score
#      15 x_train, x_test, y_train, y_test = train_test_split(
#      16     X, y, test_size=0.2, random_state=42
#      17 )
# ---> 19 pipeline.fit(x_train, y_train)
#      21 y_pred = pipeline.predict(x_test)
#      23 acc = accuracy_score(y_test, y_pred)
#
# NameError: name 'pipeline' is not defined
